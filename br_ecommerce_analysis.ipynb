# %% [markdown]
# # Analysis

# %%
import pandas as pd
import numpy as np
# import warnings
# warnings.filterwarnings('ignore')

# %%
df_products = pd.read_csv('archive/olist_products_dataset.csv')
df_product_category_name_en = pd.read_csv('archive/product_category_name_translation.csv')
df_sellers = pd.read_csv('archive/olist_sellers_dataset.csv')
df_customers = pd.read_csv('archive/olist_customers_dataset.csv')
df_geolocation = pd.read_csv('archive/olist_geolocation_dataset.csv')
df_orders = pd.read_csv('archive/olist_orders_dataset.csv')
df_order_items = pd.read_csv('archive/olist_order_items_dataset.csv')
df_order_payments = pd.read_csv('archive/olist_order_payments_dataset.csv')
df_order_reviews = pd.read_csv('archive/olist_order_reviews_dataset.csv')

# %% [markdown]
# ## Data Profiling

# %% [markdown]
# Перевірка типів даних у кожній таблиці:

# %%
dfs = {
    "products": df_products,
    "product_category_name_en": df_product_category_name_en,
    "sellers": df_sellers,
    "customers": df_customers,
    "geolocation": df_geolocation,
    "orders": df_orders,
    "order_items": df_order_items,
    "order_payments": df_order_payments,
    "order_reviews": df_order_reviews
}

for name, df in dfs.items():
    print(f"--- {name} ---")
    print(df.dtypes)
    print(df.isna().sum())
    print(df.duplicated().sum())
    print(df.shape)
# Out:
# --- products ---
# product_id                     object
# product_category_name          object
# product_name_lenght           float64
# product_description_lenght    float64
# product_photos_qty            float64
# product_weight_g              float64
# product_length_cm             float64
# product_height_cm             float64
# product_width_cm              float64
# dtype: object
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64
# 0
# (32951, 9)
# --- product_category_name_en ---
# product_category_name            object
# product_category_name_english    object
# dtype: object
# product_category_name            0
# product_category_name_english    0
# dtype: int64
# 0
# (71, 2)
# ...

# %%
df_geolocation = df_geolocation.drop_duplicates()

# %% [markdown]
# ### Products

# %%
df_products = df_products.dropna()
df_products.isna().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %% [markdown]
# ### Orders

# %%
df_orders[df_orders['order_approved_at'].isna()]
# Out:
#                                order_id                       customer_id  \
# 1130   00b1cb0320190ca0daa2c88b35206009  3532ba38a3fd242259a514ac2b6ae6b6
# 1801   ed3efbd3a87bea76c2812c66a0b32219  191984a8ba4cbb2145acb4fe35b69664
# 1868   df8282afe61008dc26c6c31011474d02  aa797b187b5466bc6925aaaa4bb3bed1
# 2029   8d4c637f1accf7a88a4555f02741e606  b1dd715db389a2077f43174e7a675d07
# 2161   7a9d4c7f9b068337875b95465330f2fc  7f71ae48074c0cfec9195f88fcbfac55
# ...                                 ...                               ...
# 97696  5a00b4d35edffc56b825c3646a99ba9d  6a3bdf004ca96338fb5fad1b8d93c2e6
# 98415  227c804e2a44760671a6a5697ea549e4  62e7477e75e542243ee62a0ba73f410f
# 98909  e49e7ce1471b4693482d40c2bd3ad196  e4e7ab3f449aeb401f0216f86c2104db
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
#
#       order_status order_purchase_timestamp order_approved_at  \
# ...

# %% [markdown]
# Отже, ці замовлення були відмінені.

# %%
df_orders[df_orders['order_delivered_customer_date'].isna()]
# Out:
#                                order_id                       customer_id  \
# 6      136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 44     ee64d42b8cf066f35eac1cf57de1aa85  caded193e8e47b8362864762a83db3c5
# 103    0760a852e4e9d89eb77bf631eaaf1c84  d2a79636084590b7465af8ab374a8cf5
# 128    15bed8e2fec7fdbadb186b57c46c92f2  f3f0e613e0bdb9c7cee75504f0f90679
# 154    6942b8da583c2f9957e990d028607019  52006a9383bf149a4fb24226b173106f
# ...                                 ...                               ...
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99313  e9e64a17afa9653aacf2616d94c005b8  b4cd0522e632e481f8eaf766a2646e86
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
# 99348  a69ba794cc7deb415c3e15a0a3877e69  726f0894b5becdf952ea537d5266e543
# 99415  5fabc81b6322c8443648e1b21a6fef21  32c9df889d41b0ee8309a5efb6855dcb
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
df_products_en = df_products.merge(df_product_category_name_en, how= 'left', on='product_category_name')
df_products_en['product_category_name'] = df_products_en['product_category_name_english']
df_products_en.drop(columns='product_category_name_english')
# Out:
#                              product_id      product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                  perfumery
# 1      3aa071139cb16b67ca9e5dea641aaa2f                        art
# 2      96bd76ec8810374ed1b65e291975717f             sports_leisure
# 3      cef67bcfe19066a932b7673e239eb23d                       baby
# 4      9dc1a7de274444849c219cff195d0b71                 housewares
# ...                                 ...                        ...
# 32335  a0b7d5a992ccda646f2d34e418fff5a0            furniture_decor
# 32336  bf4538d88321d0fd4412a93c974510e6  construction_tools_lights
# 32337  9a7c6041fa9592d9d9ef6cfe62a71f8c             bed_bath_table
# 32338  83808703fc0706a22e264b9d75f04a2e      computers_accessories
# 32339  106392145fca363410d287a815be6de4             bed_bath_table
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                     40.0                       287.0                 1.0
# ...

# %%
df_order_reviews = df_order_reviews.fillna('no comment')

# %%
# products
df_products['product_name_lenght'] = df_products['product_name_lenght'].astype('int64')
df_products['product_description_lenght'] = df_products['product_description_lenght'].astype('int64')
df_products['product_photos_qty'] = df_products['product_photos_qty'].astype('int64')

# orders
df_orders['order_status'] = df_orders['order_status'].astype('category')
df_orders['order_purchase_timestamp'] = pd.to_datetime(df_orders['order_purchase_timestamp'], errors='coerce')
df_orders['order_approved_at'] = pd.to_datetime(df_orders['order_approved_at'], errors='coerce')
df_orders['order_delivered_customer_date'] = pd.to_datetime(df_orders['order_delivered_customer_date'], errors='coerce')
df_orders['order_delivered_carrier_date'] = pd.to_datetime(df_orders['order_delivered_carrier_date'], errors='coerce')
df_orders['order_estimated_delivery_date'] = pd.to_datetime(df_orders['order_estimated_delivery_date'], errors='coerce')

# order_items
df_order_items['shipping_limit_date'] = pd.to_datetime(df_order_items['shipping_limit_date'], errors='coerce')

# order_payments
df_order_payments['payment_type'] = df_order_payments['payment_type'].astype('category')

# order_reviews
df_order_reviews['review_creation_date'] = pd.to_datetime(df_order_reviews['review_creation_date'], errors='coerce')
df_order_reviews['review_answer_timestamp'] = pd.to_datetime(df_order_reviews['review_answer_timestamp'], errors='coerce')

# %%
df_order_reviews['feedback_time'] = df_order_reviews['review_answer_timestamp'] - df_order_reviews['review_creation_date']
df_order_reviews.head(3)
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
#
#    review_score review_comment_title review_comment_message  \
# 0             4           no comment             no comment
# 1             5           no comment             no comment
# 2             5           no comment             no comment
#
#   review_creation_date review_answer_timestamp   feedback_time
# 0           2018-01-18     2018-01-18 21:46:59 0 days 21:46:59
# 1           2018-03-10     2018-03-11 03:05:13 1 days 03:05:13
# 2           2018-02-17     2018-02-18 14:36:24 1 days 14:36:24

# %%
def is_on_time(row):
    if pd.isna(row['order_delivered_customer_date']) or pd.isna(row['order_estimated_delivery_date']):
        return 'no infо'
    elif row['order_delivered_customer_date'] <= row['order_estimated_delivery_date']:
        return True
    else:
        return False

# %%
df_orders['delivery_time'] = df_orders['order_delivered_customer_date'] - df_orders['order_purchase_timestamp']
df_orders['on_time'] = df_orders.apply(is_on_time, axis=1)
df_orders.head(10)
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# 5  a4591c265e18cb1dcee52889e2d8acc3  503740e9ca751ccdda7ba28e9ab8f608
# 6  136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 7  6514b8ad8028c9f2cc2374ded245783f  9bdf08b4b3b52b5526ff42d37d47f222
# 8  76c6e866289321a7c93b82b54852dc33  f54a9f0e6b351c431402b8461ea51999
# 9  e69bfb5eb88e0ed6a785585b27e16dbf  31ad1d1b63eb9962463f764d4e6e0c9d
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# ...
